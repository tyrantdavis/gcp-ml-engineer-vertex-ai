# %% [markdown]
# <a href="https://colab.research.google.com/github/tyrantdavis/gcp-ml-engineer-vertex-ai/blob/main/notebooks/training/vertex_ai_training_only.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vertex AI Training Only
